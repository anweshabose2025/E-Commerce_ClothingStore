# %%
print("Anwesha")
# Out:
# Anwesha

# %%
from pymongo.mongo_client import MongoClient
#from pymongo.server_api import ServerApi

uri = "mongodb+srv://anweshabbose2025_db_user:IMISH9lCyUOotqDV@e-commerce-clothing-sto.3rwlinl.mongodb.net/?appName=e-commerce-clothing-store"

# Create a new client and connect to the server
client = MongoClient(uri)#, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
##try:
##    client.admin.command('ping')
##    print("Pinged your deployment. You successfully connected to MongoDB!")
##except Exception as e:
##    print(e)

# %%
db = client["test_ecom_db"]
collection = db["products"]
print("connected to mongo-db")
# Out:
# connected to mongo-db

# %%
product = {
    "name":"Men Casual Shirt",
    "price": 900,
    "category":"men"
    }
collection.insert_one(product)
# Out:
# InsertOneResult(ObjectId('69f5ac4e9e700241bdcbc25c'), acknowledged=True)

# %%
products = [
    {"name": "Jeans", "price": 1499, "category": "men"},
    {"name": "Kurti", "price": 999, "category": "women"},
    {"name": "Kids Jacket", "price": 1299, "category": "kids"}
]

collection.insert_many(products)

print("Multiple Products Inserted ✅")
# Out:
# Multiple Products Inserted ✅

# %%
# 🧪 🔹 CELL 6 — View All Products
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('69f5ac4e9e700241bdcbc25c'), 'name': 'Men Casual Shirt', 'price': 900, 'category': 'men'}
# {'_id': ObjectId('69f5b0b39e700241bdcbc25d'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('69f5b0b39e700241bdcbc25e'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('69f5b0b39e700241bdcbc25f'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %%
product = collection.find_one({"name":"Jeans"})
print(product)
# Out:
# {'_id': ObjectId('69f5b0b39e700241bdcbc25d'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}

# %%
product = collection.find({'category': 'men'})
for p in product:
    print(p)
# Out:
# {'_id': ObjectId('69f5ac4e9e700241bdcbc25c'), 'name': 'Men Casual Shirt', 'price': 900, 'category': 'men'}
# {'_id': ObjectId('69f5b0b39e700241bdcbc25d'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}

# %%
collection.update_one(
    {"name": "Jeans"},
    {"$set": {"price": 1399}}
)

print("Product Updated ✅")
# Out:
# Product Updated ✅

# %%
product = collection.find({'category': 'men'})
for p in product:
    print(p)
# Out:
# {'_id': ObjectId('69f5ac4e9e700241bdcbc25c'), 'name': 'Men Casual Shirt', 'price': 900, 'category': 'men'}
# {'_id': ObjectId('69f5b0b39e700241bdcbc25d'), 'name': 'Jeans', 'price': 1399, 'category': 'men'}

# %%
collection.delete_one({"name": "Kids Jacket"})

print("Product Deleted ✅")
# Out:
# Product Deleted ✅

# %%
collection.delete_many({})

print("All Products Deleted ✅")

# %%
collection.drop()

print("Collection Dropped ✅")
